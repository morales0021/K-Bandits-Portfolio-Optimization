# %% [markdown]
# # Research Bandits
#
# - This notebook analyses porfolio performance of 24 stocks from 2013 to 2023.
# - The 24 stocks are selected dynamically every two weeks w.r.t to a group of clusters.
# - The clusters are recreated every year w.r.t the 120 more performing stocks from the previous year.
#
# Note : In this notebook we consider 20 simulations per year in the bandit selection criteria

# %%
import os
import sys
path = '/'.join(os.path.abspath('').split('/')[0:-2])
print(path)
sys.path.append(path)

import pickle
import pandas as pd
import json
import random, tqdm
import numpy as np

from experts.alpha import alpha
from exploration.explore import explore
from exploration.outils import stats

import plotly.express as px
# Out:
# /home/mora/Documents/projects/Bandits

# %%
N_SIMS = 20

# %%
with open('../../../datasharing/tickers.json','r') as file:
    tickers = json.load(file)

tickers = tickers["sp500"]

# %%
# Load the pickle file that contains the full data for each stock
with open('../../../datasharing/hist_stock_data.pkl','rb') as file:
    df_hst_tickers = pickle.load(file)

# Chose the label "Close" as the main label to analyse the price series
label = 'Close'
df_close_stocks = pd.DataFrame([])
for key, df in df_hst_tickers.items():
    df_close_stocks = pd.concat([df_close_stocks,
                                 df[label]], axis = 1)

# Create a single data frame that cotains the series data from all the SP500 stocks
df_close_stocks.columns = list(df_hst_tickers.keys())
df_close_stocks['date'] = df_close_stocks.index
df_close_stocks.index = pd.to_datetime(df_close_stocks['date'])


df_close_stocks = pd.DataFrame()

for ticker in tickers:
    srs = df_hst_tickers[ticker][['Close']]
    srs.columns = [ticker]
    df_close_stocks = pd.concat([df_close_stocks,srs], axis = 1)
    
df_close_stocks.reset_index(inplace = True)
df_close_stocks['date'] = pd.to_datetime(df_close_stocks['Date'])

# Resample series in terms of 2Weeks
df_close_stocks.set_index('date', inplace = True)
df_2w = df_close_stocks.resample("2W").last()

# %%
# Creating the function that compute the statistics
def get_stats(df_close_stocks, tickers: dict, years: list = None,
              inter = None, freq:str = 'M', min_els:int = 6) -> dict:
    """
    This function produces some statistics using a dataframe fille with stocks.
    Precisely the average mean return and the sharpe ratio.
    Args:
        df_hst_tickers (dict) - contains dataframes for multiple stocks
        tickers (list) - the list of tickers to compute the statistics 
        years (list) - the list of years to compute the statistics
        inter (slice) - A slice that precises the data indexs to compute the statistics
        freq (str) - the frequency for the statistics (Y,M,W,2W, ...)
        min_els(int) - the minimum quantity of elements in the series required
            after the frequency postprocessing.
    """
    st_stats = {}
    for ticker in tickers:
        if years:
            tmp_df = df_close_stocks[df_close_stocks['Date'].dt.year.isin(years)]
        elif inter:
            tmp_df = df_close_stocks.iloc[inter]

        pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()

        # discart ticket if not enough data
        if pc_m.shape[0] < min_els:
            continue
            
        av_ret = pc_m.mean()
        sr = av_ret / pc_m.std()
        st_stats[ticker] = {"sr":sr, 'av_ret':av_ret}
            
    return st_stats

def df_and_sort(st_stats: dict, col: str) -> pd.DataFrame :
    """
    Function that creates a dataframe using a dictionary of stocks with statistics
    metrics and sort the dataframe based on the column name precised.
    Args:
        st_stats (dict) - The dictionary containing the statistics.
        col (str) - The name of the column for sorting.
    """
    df_stats = pd.DataFrame(st_stats).transpose()
    df_stats.sort_values(by=col, inplace = True, ascending = False)
    return df_stats


def create_stock_groups(lst_stocks: list, basket_size: int,
                        max_stocks: int):
    """
    Create multiple group of stocks with basket_size elements
    inside each group.
    Args:
        lst_stocks (list) : List of stocks
        basket_size (int): The total element of stocks in
            each basket.
    """
    
    random.shuffle(tst)
    stcks = {'stocks_dict':list(tst), 'groups':{}}

    for i in range(0,max_stocks,basket_size):
        stcks['groups'].update({i:list(tst[i:i+basket_size])})
    
    return stcks


def simulate_year(df_series, years: list, n_sims: int,
                  stock_groups: dict, exploration_rate: float,
                  p_alpha: float):

    df_test = df_series[df_series['Date'].dt.year.isin(years)]
    lines = []

    for group, lst_stocks in stock_groups['groups'].items():

        df_bandits = df_test[lst_stocks].pct_change(1).dropna()

        if df_bandits.shape[0] == 0:
            continue

        arguments = {"exploration_rate": exploration_rate,
                     "n_bandit":df_bandits.shape[1],
                     "steps":df_bandits.shape[0],
                     "alpha":p_alpha,
                     "df_bandits":df_bandits
                    }


        exp = explore(alpha.execute)
        exp.execute(n_sims, **arguments)
        mean, std = stats(exp.rets_compo)
        line = [arguments["alpha"],
                arguments["exploration_rate"],
                mean,
                std]

        lines.append(line)

    df_rets = pd.DataFrame(lines)
    df_rets.columns = ["alpha", "expl", "mean", "std"]
    
    return df_rets.mean()

# %%
# Create a group of stocks
max_stocks = 120
stock_groups = {}
basket_size = 5
metric = 'sr' # choose between 'av_ret' or 'sr'

for year in tqdm.tqdm(range(2012,2024)):

    years_tr = list(range(year - 10, year))
    stats_tr = get_stats(df_close_stocks, tickers, years = years_tr)
    df_stats_tr = df_and_sort(stats_tr, metric)
    tst = df_stats_tr.index[0:max_stocks].values
    stock_groups[year] = create_stock_groups(tickers,
                                             basket_size,
                                             max_stocks)
# Out:
#   0%|                                                    | 0/12 [00:00<?, ?it/s]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#   8%|███▋                                        | 1/12 [00:01<00:17,  1.55s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  17%|███████▎                                    | 2/12 [00:03<00:15,  1.53s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  25%|███████████                                 | 3/12 [00:04<00:13,  1.53s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# ...
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  58%|█████████████████████████▋                  | 7/12 [00:10<00:07,  1.53s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  67%|█████████████████████████████▎              | 8/12 [00:12<00:06,  1.52s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  75%|█████████████████████████████████           | 9/12 [00:13<00:04,  1.52s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  83%|███████████████████████████████████▊       | 10/12 [00:15<00:03,  1.51s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
#  92%|███████████████████████████████████████▍   | 11/12 [00:16<00:01,  1.52s/it]/tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# /tmp/ipykernel_3903946/4208589238.py:23: FutureWarning: The default fill_method='pad' in Series.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   pc_m = tmp_df[ticker].pct_change(periods = 1, freq = freq).dropna()
# 100%|███████████████████████████████████████████| 12/12 [00:18<00:00,  1.52s/it]

# %%
stock_groups
# Out:
# {2012: {'stocks_dict': ['CTRA',
#    'CRM',
#    'TPR',
#    'LKQ',
#    'WFC',
#    'CME',
#    'WELL',
#    'STLD',
#    'TSLA',
#    'FRT',
#    'LIN',
#    'CSX',
#    'ODFL',
#    'NKE',
#    'APD',
#    'NUE',
#    'TROW',
#    'CBRE',
#    'CHTR',
#    'ACGL',
#    'JBHT',
#    'EQR',
#    'ROK',
#    'IRM',
#    'AZO',
#    'OKE',
#    'MO',
#    'MMM',
#    'SPG',
#    'ANSS',
#    'CMG',
#    'AWK',
#    'DG',
#    'HUM',
#    'NDSN',
#    'TDY',
#    'PEAK',
#    'TYL',
#    'TSCO',
#    'LYB',
#    'RTX',
#    'CHRW',
#    'CPT',
#    'DFS',
#    'AMZN',
#    'NEE',
#    'DVA',
#    'NVR',
#    'DHR',
#    'SBUX',
#    'CNC',
#    'ED',
#    'AON',
#    'MNST',
#    'PSA',
#    'UDR',
#    'FSLR',
#    'GWW',
#    'MA',
#    'CTSH',
#    'ICE',
#    'LULU',
#    'ORLY',
#    'IDXX',
#    'WRB',
#    'GILD',
#    'ROST',
#    'CB',
#    'EXR',
#    'CAT',
#    'K',
#    'TRMB',
#    'HUBB',
#    'PM',
#    'ELV',
#    'UNP',
#    'EL',
#    'ECL',
#    'NXPI',
#    'JNJ',
#    'EW',
#    'SYK',
#    'OXY',
#    'XRAY',
#    'SHW',
#    'CHD',
#    'EIX',
#    'ULTA',
#    'BXP',
#    'NSC',
#    'SO',
#    'HSIC',
#    'LMT',
#    'FAST',
#    'YUM',
#    'AVB',
#    'MAA',
#    'BIO',
#    'ATO',
#    'AME',
#    'TRGP',
#    'WEC',
#    'GNRC',
#    'DLR',
#    'NFLX',
#    'KDP',
#    'ISRG',
#    'BRO',
#    'WYNN',
#    'FTNT',
#    'AVGO',
#    'VRSK',
#    'O',
#    'EQT',
#    'VTR',
#    'EOG',
#    'ESS',
#    'WAB',
#    'AAPL',
#    'ROL'],
#   'groups': {0: ['CTRA', 'CRM', 'TPR', 'LKQ', 'WFC'],
#    5: ['CME', 'WELL', 'STLD', 'TSLA', 'FRT'],
#    10: ['LIN', 'CSX', 'ODFL', 'NKE', 'APD'],
#    15: ['NUE', 'TROW', 'CBRE', 'CHTR', 'ACGL'],
#    20: ['JBHT', 'EQR', 'ROK', 'IRM', 'AZO'],
#    25: ['OKE', 'MO', 'MMM', 'SPG', 'ANSS'],
#    30: ['CMG', 'AWK', 'DG', 'HUM', 'NDSN'],
#    35: ['TDY', 'PEAK', 'TYL', 'TSCO', 'LYB'],
#    40: ['RTX', 'CHRW', 'CPT', 'DFS', 'AMZN'],
#    45: ['NEE', 'DVA', 'NVR', 'DHR', 'SBUX'],
#    50: ['CNC', 'ED', 'AON', 'MNST', 'PSA'],
#    55: ['UDR', 'FSLR', 'GWW', 'MA', 'CTSH'],
#    60: ['ICE', 'LULU', 'ORLY', 'IDXX', 'WRB'],
#    65: ['GILD', 'ROST', 'CB', 'EXR', 'CAT'],
#    70: ['K', 'TRMB', 'HUBB', 'PM', 'ELV'],
#    75: ['UNP', 'EL', 'ECL', 'NXPI', 'JNJ'],
#    80: ['EW', 'SYK', 'OXY', 'XRAY', 'SHW'],
#    85: ['CHD', 'EIX', 'ULTA', 'BXP', 'NSC'],
#    90: ['SO', 'HSIC', 'LMT', 'FAST', 'YUM'],
#    95: ['AVB', 'MAA', 'BIO', 'ATO', 'AME'],
#    100: ['TRGP', 'WEC', 'GNRC', 'DLR', 'NFLX'],
#    105: ['KDP', 'ISRG', 'BRO', 'WYNN', 'FTNT'],
#    110: ['AVGO', 'VRSK', 'O', 'EQT', 'VTR'],
#    115: ['EOG', 'ESS', 'WAB', 'AAPL', 'ROL']}},
#  2013: {'stocks_dict': ['ACN',
#    'CHD',
#    'TYL',
#    'FTNT',
#    'AMT',
#    'WYNN',
#    'NFLX',
#    'TRGP',
#    'CI',
#    'PSX',
#    'AWK',
#    'LULU',
#    'ROK',
#    'XRAY',
#    'ANSS',
#    'VTR',
#    'NUE',
#    'JBHT',
#    'AME',
#    'CPB',
#    'RTX',
#    'CMG',
#    'GPC',
#    'MCD',
#    'AAPL',
#    'ESS',
#    'APH',
#    'DVA',
#    'ROST',
#    'ULTA',
#    'KDP',
#    'CAT',
#    'ECL',
#    'AVB',
#    'CNC',
#    'ICE',
#    'URI',
#    'ILMN',
#    'GILD',
#    'PPG',
#    'SPG',
#    'DFS',
#    'LYB',
#    'NXPI',
#    'SRE',
#    'CRM',
#    'LIN',
#    'CPT',
#    'EW',
#    'BKNG',
#    'TDG',
#    'TSCO',
#    'ORLY',
#    'WELL',
#    'YUM',
#    'IDXX',
#    'LKQ',
#    'NSC',
#    'BXP',
#    'GWW',
#    'OKE',
#    'CHTR',
#    'TDY',
#    'FAST',
#    'PNR',
#    'WEC',
#    'WMB',
#    'AON',
#    'WAB',
#    'AMZN',
#    'CBRE',
#    'MTD',
#    'SBAC',
#    'EQR',
#    'CTRA',
#    'LH',
#    'WRB',
#    'EIX',
#    'CME',
#    'TRMB',
#    'NKE',
#    'EVRG',
#    'FRT',
#    'EL',
#    'SHW',
#    'O',
#    'APTV',
#    'PSA',
#    'FLT',
#    'NDSN',
#    'HAS',
#    'HUBB',
#    'MA',
#    'ROP',
#    'COST',
#    'EXR',
#    'CB',
#    'CMI',
#    'PEAK',
#    'TROW',
#    'CCI',
#    'AVGO',
#    'ROL',
#    'ODFL',
#    'VRSK',
#    'FSLR',
#    'DLR',
#    'EOG',
#    'MNST',
#    'CPRT',
#    'GNRC',
#    'V',
#    'ISRG',
#    'NEE',
#    'ACGL',
#    'XEL',
#    'UNP',
#    'CSX',
#    'CHRW',
#    'JKHY'],
#   'groups': {0: ['ACN', 'CHD', 'TYL', 'FTNT', 'AMT'],
#    5: ['WYNN', 'NFLX', 'TRGP', 'CI', 'PSX'],
#    10: ['AWK', 'LULU', 'ROK', 'XRAY', 'ANSS'],
#    15: ['VTR', 'NUE', 'JBHT', 'AME', 'CPB'],
#    20: ['RTX', 'CMG', 'GPC', 'MCD', 'AAPL'],
#    25: ['ESS', 'APH', 'DVA', 'ROST', 'ULTA'],
#    30: ['KDP', 'CAT', 'ECL', 'AVB', 'CNC'],
#    35: ['ICE', 'URI', 'ILMN', 'GILD', 'PPG'],
#    40: ['SPG', 'DFS', 'LYB', 'NXPI', 'SRE'],
#    45: ['CRM', 'LIN', 'CPT', 'EW', 'BKNG'],
#    50: ['TDG', 'TSCO', 'ORLY', 'WELL', 'YUM'],
#    55: ['IDXX', 'LKQ', 'NSC', 'BXP', 'GWW'],
#    60: ['OKE', 'CHTR', 'TDY', 'FAST', 'PNR'],
#    65: ['WEC', 'WMB', 'AON', 'WAB', 'AMZN'],
#    70: ['CBRE', 'MTD', 'SBAC', 'EQR', 'CTRA'],
#    75: ['LH', 'WRB', 'EIX', 'CME', 'TRMB'],
#    80: ['NKE', 'EVRG', 'FRT', 'EL', 'SHW'],
#    85: ['O', 'APTV', 'PSA', 'FLT', 'NDSN'],
#    90: ['HAS', 'HUBB', 'MA', 'ROP', 'COST'],
#    95: ['EXR', 'CB', 'CMI', 'PEAK', 'TROW'],
#    100: ['CCI', 'AVGO', 'ROL', 'ODFL', 'VRSK'],
#    105: ['FSLR', 'DLR', 'EOG', 'MNST', 'CPRT'],
#    110: ['GNRC', 'V', 'ISRG', 'NEE', 'ACGL'],
#    115: ['XEL', 'UNP', 'CSX', 'CHRW', 'JKHY']}},
#  2014: {'stocks_dict': ['TRMB',
#    'ATO',
#    'ZTS',
#    'NOW',
#    'CPRT',
#    'ROST',
#    'GWW',
#    'ISRG',
#    'DVA',
#    'TRGP',
#    'SBAC',
#    'MA',
#    'LKQ',
#    'AWK',
#    'NEE',
#    'ACN',
#    'NSC',
#    'CCI',
#    'TSCO',
#    'MTD',
#    'AMT',
#    'FANG',
#    'CPB',
#    'AJG',
#    'ABBV',
#    'ILMN',
#    'FSLR',
#    'ORLY',
#    'YUM',
#    'SHW',
#    'PPG',
#    'CHRW',
#    'ESS',
#    'XRAY',
#    'ROL',
#    'DLR',
#    'MMC',
#    'CHD',
#    'NCLH',
#    'LIN',
#    'TYL',
#    'ROP',
#    'EQIX',
#    'V',
#    'ECL',
#    'TMO',
#    'JKHY',
#    'AZO',
#    'TJX',
#    'APTV',
#    'AVGO',
#    'OKE',
#    'AME',
#    'NDAQ',
#    'LMT',
#    'SNA',
#    'CRM',
#    'WST',
#    'GILD',
#    'PNR',
#    'EXR',
#    'HCA',
#    'FLT',
#    'COR',
#    'ACGL',
#    'NUE',
#    'VRSK',
#    'DUK',
#    'ICE',
#    'PSX',
#    'CMG',
#    'CB',
#    'FAST',
#    'O',
#    'SRE',
#    'LYB',
#    'AAPL',
#    'PNW',
#    'NXPI',
#    'REGN',
#    'TDY',
#    'AMCR',
#    'BKNG',
#    'TSLA',
#    'GIS',
#    'TECH',
#    'URI',
#    'JBHT',
#    'WEC',
#    'WRB',
#    'UNP',
#    'ANSS',
#    'AOS',
#    'VFC',
#    'CSX',
#    'NKE',
#    'ODFL',
#    'ROK',
#    'GNRC',
#    'FTNT',
#    'GPC',
#    'WYNN',
#    'RTX',
#    'WAB',
#    'CTRA',
#    'APD',
#    'EMR',
#    'MNST',
#    'NDSN',
#    'DFS',
#    'EOG',
#    'HUBB',
#    'MO',
#    'CHTR',
#    'FMC',
#    'AON',
#    'IDXX',
#    'PSA',
#    'IEX',
#    'TDG'],
#   'groups': {0: ['TRMB', 'ATO', 'ZTS', 'NOW', 'CPRT'],
#    5: ['ROST', 'GWW', 'ISRG', 'DVA', 'TRGP'],
#    10: ['SBAC', 'MA', 'LKQ', 'AWK', 'NEE'],
#    15: ['ACN', 'NSC', 'CCI', 'TSCO', 'MTD'],
#    20: ['AMT', 'FANG', 'CPB', 'AJG', 'ABBV'],
#    25: ['ILMN', 'FSLR', 'ORLY', 'YUM', 'SHW'],
#    30: ['PPG', 'CHRW', 'ESS', 'XRAY', 'ROL'],
#    35: ['DLR', 'MMC', 'CHD', 'NCLH', 'LIN'],
#    40: ['TYL', 'ROP', 'EQIX', 'V', 'ECL'],
#    45: ['TMO', 'JKHY', 'AZO', 'TJX', 'APTV'],
#    50: ['AVGO', 'OKE', 'AME', 'NDAQ', 'LMT'],
#    55: ['SNA', 'CRM', 'WST', 'GILD', 'PNR'],
#    60: ['EXR', 'HCA', 'FLT', 'COR', 'ACGL'],
#    65: ['NUE', 'VRSK', 'DUK', 'ICE', 'PSX'],
#    70: ['CMG', 'CB', 'FAST', 'O', 'SRE'],
#    75: ['LYB', 'AAPL', 'PNW', 'NXPI', 'REGN'],
#    80: ['TDY', 'AMCR', 'BKNG', 'TSLA', 'GIS'],
#    85: ['TECH', 'URI', 'JBHT', 'WEC', 'WRB'],
#    90: ['UNP', 'ANSS', 'AOS', 'VFC', 'CSX'],
#    95: ['NKE', 'ODFL', 'ROK', 'GNRC', 'FTNT'],
#    100: ['GPC', 'WYNN', 'RTX', 'WAB', 'CTRA'],
#    105: ['APD', 'EMR', 'MNST', 'NDSN', 'DFS'],
#    110: ['EOG', 'HUBB', 'MO', 'CHTR', 'FMC'],
#    115: ['AON', 'IDXX', 'PSA', 'IEX', 'TDG']}},
#  2015: {'stocks_dict': ['SNA',
#    'MO',
#    'AMT',
#    'SHW',
#    'CDW',
#    'PSX',
#    'BXP',
#    'AOS',
#    'NEE',
#    'AVGO',
#    'WELL',
#    'DVA',
#    'GILD',
#    'LMT',
#    'CMS',
#    'APTV',
#    'TDY',
#    'ACGL',
#    'ORLY',
#    'EIX',
#    'ICE',
#    'NDAQ',
#    'ODFL',
#    'PSA',
#    'ROL',
#    'AAPL',
#    'EQR',
#    'IDXX',
#    'TRGP',
#    'LNT',
#    'LKQ',
#    'FAST',
#    'SBAC',
#    'ILMN',
#    'FRT',
#    'GWW',
#    'CB',
#    'TSCO',
#    'ES',
#    'IQV',
#    'O',
#    'CTRA',
#    'CSX',
#    'TECH',
#    'WRB',
#    'TDG',
#    'WEC',
#    'TYL',
#    'NXPI',
#    'URI',
#    'CPRT',
#    'CMG',
#    'MA',
#    'CNP',
#    'DIS',
#    'GNRC',
#    'CHRW',
#    'VRSK',
#    'SRE',
#    'FLT',
#    'CHD',
#    'UNP',
#    'ABBV',
#    'CHTR',
#    'AMCR',
#    'OKE',
#    'ANSS',
#    'EXR',
#    'JKHY',
#    'FTNT',
#    'DLR',
#    'GPC',
#    'PANW',
#    'SO',
#    'FANG',
#    'NKE',
#    'ESS',
#    'ROP',
#    'HCA',
#    'ROST',
#    'LIN',
#    'COR',
#    'DFS',
#    'NSC',
#    'CRM',
#    'CPT',
#    'AON',
#    'EQIX',
#    'CL',
#    'AWK',
#    'DTE',
#    'NI',
#    'ENPH',
#    'REGN',
#    'TSLA',
#    'BKNG',
#    'DUK',
#    'LYB',
#    'LUV',
#    'NCLH',
#    'SPG',
#    'APD',
#    'EOG',
#    'WAB',
#    'XEL',
#    'TJX',
#    'AME',
#    'PPG',
#    'MMC',
#    'ECL',
#    'NOW',
#    'AZO',
#    'ED',
#    'ATO',
#    'HUBB',
#    'HSIC',
#    'PNW',
#    'VRTX',
#    'KDP',
#    'NDSN'],
#   'groups': {0: ['SNA', 'MO', 'AMT', 'SHW', 'CDW'],
#    5: ['PSX', 'BXP', 'AOS', 'NEE', 'AVGO'],
#    10: ['WELL', 'DVA', 'GILD', 'LMT', 'CMS'],
#    15: ['APTV', 'TDY', 'ACGL', 'ORLY', 'EIX'],
#    20: ['ICE', 'NDAQ', 'ODFL', 'PSA', 'ROL'],
#    25: ['AAPL', 'EQR', 'IDXX', 'TRGP', 'LNT'],
#    30: ['LKQ', 'FAST', 'SBAC', 'ILMN', 'FRT'],
#    35: ['GWW', 'CB', 'TSCO', 'ES', 'IQV'],
#    40: ['O', 'CTRA', 'CSX', 'TECH', 'WRB'],
#    45: ['TDG', 'WEC', 'TYL', 'NXPI', 'URI'],
#    50: ['CPRT', 'CMG', 'MA', 'CNP', 'DIS'],
#    55: ['GNRC', 'CHRW', 'VRSK', 'SRE', 'FLT'],
#    60: ['CHD', 'UNP', 'ABBV', 'CHTR', 'AMCR'],
#    65: ['OKE', 'ANSS', 'EXR', 'JKHY', 'FTNT'],
#    70: ['DLR', 'GPC', 'PANW', 'SO', 'FANG'],
#    75: ['NKE', 'ESS', 'ROP', 'HCA', 'ROST'],
#    80: ['LIN', 'COR', 'DFS', 'NSC', 'CRM'],
#    85: ['CPT', 'AON', 'EQIX', 'CL', 'AWK'],
#    90: ['DTE', 'NI', 'ENPH', 'REGN', 'TSLA'],
#    95: ['BKNG', 'DUK', 'LYB', 'LUV', 'NCLH'],
#    100: ['SPG', 'APD', 'EOG', 'WAB', 'XEL'],
#    105: ['TJX', 'AME', 'PPG', 'MMC', 'ECL'],
#    110: ['NOW', 'AZO', 'ED', 'ATO', 'HUBB'],
#    115: ['HSIC', 'PNW', 'VRTX', 'KDP', 'NDSN']}},
#  2016: {'stocks_dict': ['TJX',
#    'GIS',
#    'EQR',
#    'CDW',
#    'MA',
#    'CPRT',
#    'SWKS',
#    'ICE',
#    'LNT',
#    'WELL',
#    'DLR',
#    'ROP',
#    'AZO',
#    'HRL',
#    'SO',
#    'WEC',
#    'BXP',
#    'GWW',
#    'AWK',
#    'AEP',
#    'ATO',
#    'NOW',
#    'ODFL',
#    'NI',
#    'PSA',
#    'PNW',
#    'UNP',
#    'WFC',
#    'HCA',
#    'GNRC',
#    'D',
#    'TSLA',
#    'ECL',
#    'CMG',
#    'IDXX',
#    'CB',
#    'GILD',
#    'LKQ',
#    'ED',
#    'AMCR',
#    'TMO',
#    'CRM',
#    'FRT',
#    'COR',
#    'SPG',
#    'O',
#    'LUV',
#    'DTE',
#    'MMC',
#    'FSLR',
#    'VRSK',
#    'CMS',
#    'ESS',
#    'AVGO',
#    'MCD',
#    'EQIX',
#    'ACN',
#    'ACGL',
#    'DIS',
#    'HSIC',
#    'NXPI',
#    'FANG',
#    'NKE',
#    'HAS',
#    'CPB',
#    'BKNG',
#    'IQV',
#    'ROST',
#    'ORLY',
#    'REGN',
#    'PANW',
#    'TYL',
#    'WST',
#    'CPT',
#    'COST',
#    'NVR',
#    'LYB',
#    'CZR',
#    'FLT',
#    'FTNT',
#    'URI',
#    'ULTA',
#    'TSCO',
#    'CHTR',
#    'KDP',
#    'EVRG',
#    'SRE',
#    'CHD',
#    'CSX',
#    'TDG',
#    'OKE',
#    'MAA',
#    'IFF',
#    'MO',
#    'ILMN',
#    'AOS',
#    'PEAK',
#    'SNA',
#    'LMT',
#    'EW',
#    'DLTR',
#    'XEL',
#    'ROL',
#    'ES',
#    'APTV',
#    'JKHY',
#    'EXR',
#    'HD',
#    'MKTX',
#    'TDY',
#    'NEE',
#    'AVB',
#    'SHW',
#    'WAB',
#    'UDR',
#    'GPC',
#    'KMB',
#    'NDSN',
#    'DUK',
#    'FAST'],
#   'groups': {0: ['TJX', 'GIS', 'EQR', 'CDW', 'MA'],
#    5: ['CPRT', 'SWKS', 'ICE', 'LNT', 'WELL'],
#    10: ['DLR', 'ROP', 'AZO', 'HRL', 'SO'],
#    15: ['WEC', 'BXP', 'GWW', 'AWK', 'AEP'],
#    20: ['ATO', 'NOW', 'ODFL', 'NI', 'PSA'],
#    25: ['PNW', 'UNP', 'WFC', 'HCA', 'GNRC'],
#    30: ['D', 'TSLA', 'ECL', 'CMG', 'IDXX'],
#    35: ['CB', 'GILD', 'LKQ', 'ED', 'AMCR'],
#    40: ['TMO', 'CRM', 'FRT', 'COR', 'SPG'],
#    45: ['O', 'LUV', 'DTE', 'MMC', 'FSLR'],
#    50: ['VRSK', 'CMS', 'ESS', 'AVGO', 'MCD'],
#    55: ['EQIX', 'ACN', 'ACGL', 'DIS', 'HSIC'],
#    60: ['NXPI', 'FANG', 'NKE', 'HAS', 'CPB'],
#    65: ['BKNG', 'IQV', 'ROST', 'ORLY', 'REGN'],
#    70: ['PANW', 'TYL', 'WST', 'CPT', 'COST'],
#    75: ['NVR', 'LYB', 'CZR', 'FLT', 'FTNT'],
#    80: ['URI', 'ULTA', 'TSCO', 'CHTR', 'KDP'],
#    85: ['EVRG', 'SRE', 'CHD', 'CSX', 'TDG'],
#    90: ['OKE', 'MAA', 'IFF', 'MO', 'ILMN'],
#    95: ['AOS', 'PEAK', 'SNA', 'LMT', 'EW'],
#    100: ['DLTR', 'XEL', 'ROL', 'ES', 'APTV'],
#    105: ['JKHY', 'EXR', 'HD', 'MKTX', 'TDY'],
#    110: ['NEE', 'AVB', 'SHW', 'WAB', 'UDR'],
#    115: ['GPC', 'KMB', 'NDSN', 'DUK', 'FAST']}},
#  2017: {'stocks_dict': ['REGN',
#    'PNC',
#    'XEL',
#    'AWK',
#    'NDSN',
#    'ACN',
#    'AJG',
#    'TDG',
#    'URI',
#    'WM',
#    'WRB',
#    'GPC',
#    'HPE',
#    'DPZ',
#    'CINF',
#    'VRSK',
#    'SNA',
#    'GILD',
#    'AMCR',
#    'GIS',
#    'UDR',
#    'SHW',
#    'LUV',
#    'NVR',
#    'CHD',
#    'AVGO',
#    'CRM',
#    'WEC',
#    'IDXX',
#    'KMB',
#    'HUBB',
#    'PSX',
#    'MKTX',
#    'DFS',
#    'ATO',
#    'CB',
#    'APTV',
#    'COST',
#    'EXR',
#    'CMS',
#    'AEE',
#    'ROK',
#    'WAB',
#    'SRE',
#    'WFC',
#    'ESS',
#    'NI',
#    'TECH',
#    'AZO',
#    'TJX',
#    'BKNG',
#    'IEX',
#    'TYL',
#    'NXPI',
#    'O',
#    'ED',
#    'GL',
#    'NSC',
#    'LNT',
#    'MPWR',
#    'MO',
#    'CPRT',
#    'SO',
#    'PAYX',
#    'CDW',
#    'SYK',
#    'TSCO',
#    'AON',
#    'NEE',
#    'ACGL',
#    'CZR',
#    'DUK',
#    'TDY',
#    'CSX',
#    'ULTA',
#    'CFG',
#    'ROL',
#    'JKHY',
#    'ODFL',
#    'PSA',
#    'LKQ',
#    'CHTR',
#    'ORLY',
#    'ROST',
#    'UNP',
#    'AMZN',
#    'TSLA',
#    'KDP',
#    'HD',
#    'GWW',
#    'HCA',
#    'EOG',
#    'LMT',
#    'D',
#    'OKE',
#    'DTE',
#    'ROP',
#    'MA',
#    'WDC',
#    'FTNT',
#    'NOC',
#    'FAST',
#    'CPT',
#    'SWKS',
#    'PNW',
#    'EVRG',
#    'NKE',
#    'JBHT',
#    'GNRC',
#    'SPG',
#    'WELL',
#    'EQIX',
#    'PKG',
#    'LYB',
#    'MMC',
#    'EQR',
#    'FANG',
#    'ISRG',
#    'AOS',
#    'FLT'],
#   'groups': {0: ['REGN', 'PNC', 'XEL', 'AWK', 'NDSN'],
#    5: ['ACN', 'AJG', 'TDG', 'URI', 'WM'],
#    10: ['WRB', 'GPC', 'HPE', 'DPZ', 'CINF'],
#    15: ['VRSK', 'SNA', 'GILD', 'AMCR', 'GIS'],
#    20: ['UDR', 'SHW', 'LUV', 'NVR', 'CHD'],
#    25: ['AVGO', 'CRM', 'WEC', 'IDXX', 'KMB'],
#    30: ['HUBB', 'PSX', 'MKTX', 'DFS', 'ATO'],
#    35: ['CB', 'APTV', 'COST', 'EXR', 'CMS'],
#    40: ['AEE', 'ROK', 'WAB', 'SRE', 'WFC'],
#    45: ['ESS', 'NI', 'TECH', 'AZO', 'TJX'],
#    50: ['BKNG', 'IEX', 'TYL', 'NXPI', 'O'],
#    55: ['ED', 'GL', 'NSC', 'LNT', 'MPWR'],
#    60: ['MO', 'CPRT', 'SO', 'PAYX', 'CDW'],
#    65: ['SYK', 'TSCO', 'AON', 'NEE', 'ACGL'],
#    70: ['CZR', 'DUK', 'TDY', 'CSX', 'ULTA'],
#    75: ['CFG', 'ROL', 'JKHY', 'ODFL', 'PSA'],
#    80: ['LKQ', 'CHTR', 'ORLY', 'ROST', 'UNP'],
#    85: ['AMZN', 'TSLA', 'KDP', 'HD', 'GWW'],
#    90: ['HCA', 'EOG', 'LMT', 'D', 'OKE'],
#    95: ['DTE', 'ROP', 'MA', 'WDC', 'FTNT'],
#    100: ['NOC', 'FAST', 'CPT', 'SWKS', 'PNW'],
#    105: ['EVRG', 'NKE', 'JBHT', 'GNRC', 'SPG'],
#    110: ['WELL', 'EQIX', 'PKG', 'LYB', 'MMC'],
#    115: ['EQR', 'FANG', 'ISRG', 'AOS', 'FLT']}},
#  2018: {'stocks_dict': ['CPT',
#    'JNJ',
#    'NSC',
#    'TSCO',
#    'CMS',
#    'MAA',
#    'TFC',
#    'FLT',
#    'KMB',
#    'SNA',
#    'AON',
#    'ROP',
#    'WEC',
#    'CBOE',
#    'GWW',
#    'NKE',
#    'HCA',
#    'LUV',
#    'SWKS',
#    'CINF',
#    'O',
#    'NOC',
#    'PSA',
#    'IQV',
#    'WRB',
#    'EQR',
#    'WM',
#    'FAST',
#    'AMCR',
#    'MMM',
#    'PNW',
#    'JKHY',
#    'NEE',
#    'D',
#    'ROL',
#    'IT',
#    'AOS',
#    'CSGP',
#    'MTB',
#    'AWK',
#    'SHW',
#    'AEP',
#    'NVR',
#    'CRM',
#    'CDW',
#    'FTNT',
#    'IEX',
#    'ULTA',
#    'NXPI',
#    'HAS',
#    'MKTX',
#    'ODFL',
#    'NOW',
#    'MCD',
#    'ACN',
#    'HD',
#    'CHTR',
#    'FANG',
#    'JBHT',
#    'INVH',
#    'ORLY',
#    'XEL',
#    'EVRG',
#    'HPE',
#    'CMCSA',
#    'AEE',
#    'AJG',
#    'LNT',
#    'MMC',
#    'NDSN',
#    'TSLA',
#    'ATO',
#    'UDR',
#    'ES',
#    'ROST',
#    'ECL',
#    'CB',
#    'CPRT',
#    'ESS',
#    'DPZ',
#    'EFX',
#    'SNPS',
#    'DTE',
#    'DLTR',
#    'TJX',
#    'LW',
#    'AZO',
#    'TDY',
#    'CTAS',
#    'EQIX',
#    'ANET',
#    'LRCX',
#    'APTV',
#    'UNP',
#    'DFS',
#    'CZR',
#    'ACGL',
#    'SRE',
#    'DUK',
#    'SBUX',
#    'REGN',
#    'FTV',
#    'WAB',
#    'CSX',
#    'AMT',
#    'TECH',
#    'NI',
#    'URI',
#    'AVGO',
#    'GL',
#    'TYL',
#    'VRSK',
#    'LMT',
#    'OKE',
#    'EXR',
#    'CHD',
#    'ED',
#    'LYB',
#    'VFC',
#    'SO'],
#   'groups': {0: ['CPT', 'JNJ', 'NSC', 'TSCO', 'CMS'],
#    5: ['MAA', 'TFC', 'FLT', 'KMB', 'SNA'],
#    10: ['AON', 'ROP', 'WEC', 'CBOE', 'GWW'],
#    15: ['NKE', 'HCA', 'LUV', 'SWKS', 'CINF'],
#    20: ['O', 'NOC', 'PSA', 'IQV', 'WRB'],
#    25: ['EQR', 'WM', 'FAST', 'AMCR', 'MMM'],
#    30: ['PNW', 'JKHY', 'NEE', 'D', 'ROL'],
#    35: ['IT', 'AOS', 'CSGP', 'MTB', 'AWK'],
#    40: ['SHW', 'AEP', 'NVR', 'CRM', 'CDW'],
#    45: ['FTNT', 'IEX', 'ULTA', 'NXPI', 'HAS'],
#    50: ['MKTX', 'ODFL', 'NOW', 'MCD', 'ACN'],
#    55: ['HD', 'CHTR', 'FANG', 'JBHT', 'INVH'],
#    60: ['ORLY', 'XEL', 'EVRG', 'HPE', 'CMCSA'],
#    65: ['AEE', 'AJG', 'LNT', 'MMC', 'NDSN'],
#    70: ['TSLA', 'ATO', 'UDR', 'ES', 'ROST'],
#    75: ['ECL', 'CB', 'CPRT', 'ESS', 'DPZ'],
#    80: ['EFX', 'SNPS', 'DTE', 'DLTR', 'TJX'],
#    85: ['LW', 'AZO', 'TDY', 'CTAS', 'EQIX'],
#    90: ['ANET', 'LRCX', 'APTV', 'UNP', 'DFS'],
#    95: ['CZR', 'ACGL', 'SRE', 'DUK', 'SBUX'],
#    100: ['REGN', 'FTV', 'WAB', 'CSX', 'AMT'],
#    105: ['TECH', 'NI', 'URI', 'AVGO', 'GL'],
#    110: ['TYL', 'VRSK', 'LMT', 'OKE', 'EXR'],
#    115: ['CHD', 'ED', 'LYB', 'VFC', 'SO']}},
#  2019: {'stocks_dict': ['ROK',
#    'LW',
#    'AON',
#    'BR',
#    'CI',
#    'MTD',
#    'CDW',
#    'CZR',
#    'DUK',
#    'AJG',
#    'VRSK',
#    'LNT',
#    'SBUX',
#    'TDY',
#    'AME',
#    'MMM',
#    'GWW',
#    'AOS',
#    'CPT',
#    'ORLY',
#    'SHW',
#    'ACGL',
#    'MPWR',
#    'NI',
#    'PNW',
#    'AMT',
#    'CDNS',
#    'IEX',
#    'ULTA',
#    'TXN',
#    'DTE',
#    'MSFT',
#    'SNPS',
#    'TTWO',
#    'KLAC',
#    'ELV',
#    'CB',
#    'FAST',
#    'MSI',
#    'EVRG',
#    'AMZN',
#    'SRE',
#    'CPRT',
#    'V',
#    'D',
#    'ED',
#    'NVR',
#    'CNC',
#    'APTV',
#    'TSCO',
#    'XEL',
#    'A',
#    'HON',
#    'EQIX',
#    'EG',
#    'PKG',
#    'ROP',
#    'AVGO',
#    'CCI',
#    'URI',
#    'ALL',
#    'IDXX',
#    'CNP',
#    'SYK',
#    'WRB',
#    'MAR',
#    'HD',
#    'O',
#    'COO',
#    'CTAS',
#    'CHD',
#    'CSX',
#    'GL',
#    'MKTX',
#    'LMT',
#    'DFS',
#    'LRCX',
#    'RSG',
#    'ROL',
#    'AEP',
#    'WEC',
#    'AEE',
#    'APH',
#    'WM',
#    'TDG',
#    'KDP',
#    'NOC',
#    'ROST',
#    'ADBE',
#    'MA',
#    'HCA',
#    'NDSN',
#    'SWKS',
#    'CMS',
#    'EXR',
#    'AZO',
#    'ESS',
#    'NKE',
#    'NVDA',
#    'AWK',
#    'VFC',
#    'ATO',
#    'JKHY',
#    'NEE',
#    'CSGP',
#    'CINF',
#    'TYL',
#    'FTNT',
#    'UNH',
#    'FI',
#    'MMC',
#    'ES',
#    'DPZ',
#    'ECL',
#    'ODFL',
#    'ACN',
#    'PGR',
#    'ADI',
#    'CRM',
#    'TJX'],
#   'groups': {0: ['ROK', 'LW', 'AON', 'BR', 'CI'],
#    5: ['MTD', 'CDW', 'CZR', 'DUK', 'AJG'],
#    10: ['VRSK', 'LNT', 'SBUX', 'TDY', 'AME'],
#    15: ['MMM', 'GWW', 'AOS', 'CPT', 'ORLY'],
#    20: ['SHW', 'ACGL', 'MPWR', 'NI', 'PNW'],
#    25: ['AMT', 'CDNS', 'IEX', 'ULTA', 'TXN'],
#    30: ['DTE', 'MSFT', 'SNPS', 'TTWO', 'KLAC'],
#    35: ['ELV', 'CB', 'FAST', 'MSI', 'EVRG'],
#    40: ['AMZN', 'SRE', 'CPRT', 'V', 'D'],
#    45: ['ED', 'NVR', 'CNC', 'APTV', 'TSCO'],
#    50: ['XEL', 'A', 'HON', 'EQIX', 'EG'],
#    55: ['PKG', 'ROP', 'AVGO', 'CCI', 'URI'],
#    60: ['ALL', 'IDXX', 'CNP', 'SYK', 'WRB'],
#    65: ['MAR', 'HD', 'O', 'COO', 'CTAS'],
#    70: ['CHD', 'CSX', 'GL', 'MKTX', 'LMT'],
#    75: ['DFS', 'LRCX', 'RSG', 'ROL', 'AEP'],
#    80: ['WEC', 'AEE', 'APH', 'WM', 'TDG'],
#    85: ['KDP', 'NOC', 'ROST', 'ADBE', 'MA'],
#    90: ['HCA', 'NDSN', 'SWKS', 'CMS', 'EXR'],
#    95: ['AZO', 'ESS', 'NKE', 'NVDA', 'AWK'],
#    100: ['VFC', 'ATO', 'JKHY', 'NEE', 'CSGP'],
#    105: ['CINF', 'TYL', 'FTNT', 'UNH', 'FI'],
#    110: ['MMC', 'ES', 'DPZ', 'ECL', 'ODFL'],
#    115: ['ACN', 'PGR', 'ADI', 'CRM', 'TJX']}},
#  2020: {'stocks_dict': ['VRSK',
#    'ROST',
#    'MCO',
#    'LNT',
#    'DFS',
#    'PNW',
#    'ORLY',
#    'AON',
#    'BRO',
#    'MKTX',
#    'MRNA',
#    'MSI',
#    'FI',
#    'AME',
#    'AEP',
#    'GNRC',
#    'CHTR',
#    'APTV',
#    'RSG',
#    'AWK',
#    'WEC',
#    'CZR',
#    'HON',
#    'SNPS',
#    'ATO',
#    'HD',
#    'CB',
#    'GL',
#    'CTAS',
#    'V',
#    'IR',
#    'DPZ',
#    'NEE',
#    'ODFL',
#    'CPRT',
#    'SPGI',
#    'D',
#    'ROP',
#    'AEE',
#    'AVGO',
#    'EG',
#    'CSGP',
#    'TYL',
#    'AMT',
#    'PGR',
#    'MA',
#    'POOL',
#    'LW',
#    'AJG',
#    'ROL',
#    'WM',
#    'ALL',
#    'CNP',
#    'TXN',
#    'LMT',
#    'NVR',
#    'CRM',
#    'FTNT',
#    'URI',
#    'ED',
#    'DUK',
#    'JKHY',
#    'ACN',
#    'CNC',
#    'SRE',
#    'EVRG',
#    'ULTA',
#    'NKE',
#    'CDNS',
#    'CDW',
#    'PAYX',
#    'TMO',
#    'ES',
#    'GPN',
#    'SBUX',
#    'ECL',
#    'NDAQ',
#    'KLAC',
#    'ESS',
#    'ELV',
#    'SO',
#    'TJX',
#    'ACGL',
#    'NI',
#    'APH',
#    'ROK',
#    'SHW',
#    'COO',
#    'HCA',
#    'BR',
#    'EXR',
#    'IQV',
#    'DTE',
#    'XEL',
#    'CMS',
#    'FAST',
#    'MNST',
#    'CINF',
#    'ANET',
#    'GWW',
#    'PYPL',
#    'MMC',
#    'PAYC',
#    'NOW',
#    'AZO',
#    'NOC',
#    'WRB',
#    'TTWO',
#    'IDXX',
#    'VFC',
#    'MTD',
#    'UNH',
#    'IEX',
#    'TDG',
#    'VRSN',
#    'LRCX',
#    'O',
#    'PEG',
#    'HPE',
#    'TDY'],
#   'groups': {0: ['VRSK', 'ROST', 'MCO', 'LNT', 'DFS'],
#    5: ['PNW', 'ORLY', 'AON', 'BRO', 'MKTX'],
#    10: ['MRNA', 'MSI', 'FI', 'AME', 'AEP'],
#    15: ['GNRC', 'CHTR', 'APTV', 'RSG', 'AWK'],
#    20: ['WEC', 'CZR', 'HON', 'SNPS', 'ATO'],
#    25: ['HD', 'CB', 'GL', 'CTAS', 'V'],
#    30: ['IR', 'DPZ', 'NEE', 'ODFL', 'CPRT'],
#    35: ['SPGI', 'D', 'ROP', 'AEE', 'AVGO'],
#    40: ['EG', 'CSGP', 'TYL', 'AMT', 'PGR'],
#    45: ['MA', 'POOL', 'LW', 'AJG', 'ROL'],
#    50: ['WM', 'ALL', 'CNP', 'TXN', 'LMT'],
#    55: ['NVR', 'CRM', 'FTNT', 'URI', 'ED'],
#    60: ['DUK', 'JKHY', 'ACN', 'CNC', 'SRE'],
#    65: ['EVRG', 'ULTA', 'NKE', 'CDNS', 'CDW'],
#    70: ['PAYX', 'TMO', 'ES', 'GPN', 'SBUX'],
#    75: ['ECL', 'NDAQ', 'KLAC', 'ESS', 'ELV'],
#    80: ['SO', 'TJX', 'ACGL', 'NI', 'APH'],
#    85: ['ROK', 'SHW', 'COO', 'HCA', 'BR'],
#    90: ['EXR', 'IQV', 'DTE', 'XEL', 'CMS'],
#    95: ['FAST', 'MNST', 'CINF', 'ANET', 'GWW'],
#    100: ['PYPL', 'MMC', 'PAYC', 'NOW', 'AZO'],
#    105: ['NOC', 'WRB', 'TTWO', 'IDXX', 'VFC'],
#    110: ['MTD', 'UNH', 'IEX', 'TDG', 'VRSN'],
#    115: ['LRCX', 'O', 'PEG', 'HPE', 'TDY']}},
#  2021: {'stocks_dict': ['TER',
#    'V',
#    'KLAC',
#    'CPRT',
#    'HD',
#    'MSI',
#    'ECL',
#    'HON',
#    'ABT',
#    'COST',
#    'ATO',
#    'AEE',
#    'URI',
#    'NOC',
#    'TSLA',
#    'SPGI',
#    'SHW',
#    'PODD',
#    'IDXX',
#    'DTE',
#    'ELV',
#    'MNST',
#    'VRSN',
#    'AAPL',
#    'FI',
#    'NEE',
#    'CNC',
#    'WRB',
#    'FAST',
#    'TDY',
#    'MMC',
#    'AWK',
#    'LNT',
#    'FICO',
#    'ROP',
#    'MSFT',
#    'FTNT',
#    'INTU',
#    'AJG',
#    'CDAY',
#    'LMT',
#    'ANET',
#    'EQIX',
#    'ANSS',
#    'DHR',
#    'ACN',
#    'CTAS',
#    'ODFL',
#    'CSGP',
#    'SYK',
#    'LRCX',
#    'APTV',
#    'TTWO',
#    'WEC',
#    'MKTX',
#    'BRO',
#    'EXR',
#    'NI',
#    'LLY',
#    'MCO',
#    'AEP',
#    'PAYC',
#    'VRSK',
#    'RSG',
#    'ALL',
#    'SBUX',
#    'ETSY',
#    'OTIS',
#    'CZR',
#    'BR',
#    'CHTR',
#    'AVGO',
#    'NKE',
#    'UNH',
#    'XEL',
#    'GNRC',
#    'AMZN',
#    'CINF',
#    'WST',
#    'NDAQ',
#    'ADBE',
#    'TJX',
#    'MPWR',
#    'PYPL',
#    'ROL',
#    'SNPS',
#    'NOW',
#    'PAYX',
#    'ORLY',
#    'ORCL',
#    'SRE',
#    'MRNA',
#    'MSCI',
#    'IR',
#    'CARR',
#    'DPZ',
#    'POOL',
#    'CDNS',
#    'AMT',
#    'PNW',
#    'CMS',
#    'CDW',
#    'GPN',
#    'PGR',
#    'PWR',
#    'NVDA',
#    'TMO',
#    'EPAM',
#    'NSC',
#    'TYL',
#    'CHD',
#    'TXN',
#    'HCA',
#    'AON',
#    'UBER',
#    'IEX',
#    'TECH',
#    'WM',
#    'PANW',
#    'MA'],
#   'groups': {0: ['TER', 'V', 'KLAC', 'CPRT', 'HD'],
#    5: ['MSI', 'ECL', 'HON', 'ABT', 'COST'],
#    10: ['ATO', 'AEE', 'URI', 'NOC', 'TSLA'],
#    15: ['SPGI', 'SHW', 'PODD', 'IDXX', 'DTE'],
#    20: ['ELV', 'MNST', 'VRSN', 'AAPL', 'FI'],
#    25: ['NEE', 'CNC', 'WRB', 'FAST', 'TDY'],
#    30: ['MMC', 'AWK', 'LNT', 'FICO', 'ROP'],
#    35: ['MSFT', 'FTNT', 'INTU', 'AJG', 'CDAY'],
#    40: ['LMT', 'ANET', 'EQIX', 'ANSS', 'DHR'],
#    45: ['ACN', 'CTAS', 'ODFL', 'CSGP', 'SYK'],
#    50: ['LRCX', 'APTV', 'TTWO', 'WEC', 'MKTX'],
#    55: ['BRO', 'EXR', 'NI', 'LLY', 'MCO'],
#    60: ['AEP', 'PAYC', 'VRSK', 'RSG', 'ALL'],
#    65: ['SBUX', 'ETSY', 'OTIS', 'CZR', 'BR'],
#    70: ['CHTR', 'AVGO', 'NKE', 'UNH', 'XEL'],
#    75: ['GNRC', 'AMZN', 'CINF', 'WST', 'NDAQ'],
#    80: ['ADBE', 'TJX', 'MPWR', 'PYPL', 'ROL'],
#    85: ['SNPS', 'NOW', 'PAYX', 'ORLY', 'ORCL'],
#    90: ['SRE', 'MRNA', 'MSCI', 'IR', 'CARR'],
#    95: ['DPZ', 'POOL', 'CDNS', 'AMT', 'PNW'],
#    100: ['CMS', 'CDW', 'GPN', 'PGR', 'PWR'],
#    105: ['NVDA', 'TMO', 'EPAM', 'NSC', 'TYL'],
#    110: ['CHD', 'TXN', 'HCA', 'AON', 'UBER'],
#    115: ['IEX', 'TECH', 'WM', 'PANW', 'MA']}},
#  2022: {'stocks_dict': ['MMC',
#    'ROP',
#    'ODFL',
#    'SCHW',
#    'EFX',
#    'APH',
#    'WST',
#    'TDY',
#    'FDS',
#    'CCI',
#    'IR',
#    'RSG',
#    'CSGP',
#    'MSFT',
#    'SWKS',
#    'NFLX',
#    'CDNS',
#    'CDW',
#    'INTU',
#    'MSCI',
#    'OTIS',
#    'EXR',
#    'XEL',
#    'PAYC',
#    'MCO',
#    'PYPL',
#    'DPZ',
#    'ORLY',
#    'PAYX',
#    'PODD',
#    'COST',
#    'NOC',
#    'LHX',
#    'RMD',
#    'EQIX',
#    'ORCL',
#    'IDXX',
#    'FI',
#    'CZR',
#    'PANW',
#    'NEE',
#    'STX',
#    'ALL',
#    'LMT',
#    'AEE',
#    'TER',
#    'AAPL',
#    'CHTR',
#    'CINF',
#    'POOL',
#    'CRM',
#    'SPGI',
#    'FAST',
#    'MRNA',
#    'SHW',
#    'TSLA',
#    'V',
#    'LRCX',
#    'TTWO',
#    'LLY',
#    'CTAS',
#    'ANET',
#    'NOW',
#    'TT',
#    'MPWR',
#    'TXN',
#    'PLD',
#    'WRB',
#    'NI',
#    'WEC',
#    'MA',
#    'ATO',
#    'ABT',
#    'ACN',
#    'BRO',
#    'IEX',
#    'ADBE',
#    'PGR',
#    'ETSY',
#    'TMO',
#    'FTNT',
#    'CPRT',
#    'AMAT',
#    'NVR',
#    'WM',
#    'SRE',
#    'PWR',
#    'AWK',
#    'KLAC',
#    'SNPS',
#    'MTD',
#    'NKE',
#    'DHR',
#    'HD',
#    'AJG',
#    'STE',
#    'BR',
#    'CMS',
#    'TECH',
#    'VRSK',
#    'AVGO',
#    'PG',
#    'NDAQ',
#    'DTE',
#    'UNH',
#    'TYL',
#    'BLDR',
#    'MKTX',
#    'ITW',
#    'LNT',
#    'NVDA',
#    'HCA',
#    'EPAM',
#    'AVY',
#    'ROL',
#    'CARR',
#    'AMZN',
#    'ARE',
#    'VRSN',
#    'ZTS'],
#   'groups': {0: ['MMC', 'ROP', 'ODFL', 'SCHW', 'EFX'],
#    5: ['APH', 'WST', 'TDY', 'FDS', 'CCI'],
#    10: ['IR', 'RSG', 'CSGP', 'MSFT', 'SWKS'],
#    15: ['NFLX', 'CDNS', 'CDW', 'INTU', 'MSCI'],
#    20: ['OTIS', 'EXR', 'XEL', 'PAYC', 'MCO'],
#    25: ['PYPL', 'DPZ', 'ORLY', 'PAYX', 'PODD'],
#    30: ['COST', 'NOC', 'LHX', 'RMD', 'EQIX'],
#    35: ['ORCL', 'IDXX', 'FI', 'CZR', 'PANW'],
#    40: ['NEE', 'STX', 'ALL', 'LMT', 'AEE'],
#    45: ['TER', 'AAPL', 'CHTR', 'CINF', 'POOL'],
#    50: ['CRM', 'SPGI', 'FAST', 'MRNA', 'SHW'],
#    55: ['TSLA', 'V', 'LRCX', 'TTWO', 'LLY'],
#    60: ['CTAS', 'ANET', 'NOW', 'TT', 'MPWR'],
#    65: ['TXN', 'PLD', 'WRB', 'NI', 'WEC'],
#    70: ['MA', 'ATO', 'ABT', 'ACN', 'BRO'],
#    75: ['IEX', 'ADBE', 'PGR', 'ETSY', 'TMO'],
#    80: ['FTNT', 'CPRT', 'AMAT', 'NVR', 'WM'],
#    85: ['SRE', 'PWR', 'AWK', 'KLAC', 'SNPS'],
#    90: ['MTD', 'NKE', 'DHR', 'HD', 'AJG'],
#    95: ['STE', 'BR', 'CMS', 'TECH', 'VRSK'],
#    100: ['AVGO', 'PG', 'NDAQ', 'DTE', 'UNH'],
#    105: ['TYL', 'BLDR', 'MKTX', 'ITW', 'LNT'],
#    110: ['NVDA', 'HCA', 'EPAM', 'AVY', 'ROL'],
#    115: ['CARR', 'AMZN', 'ARE', 'VRSN', 'ZTS']}},
#  2023: {'stocks_dict': ['ABBV',
#    'PGR',
#    'JNJ',
#    'EA',
#    'MCO',
#    'MSFT',
#    'ABT',
#    'MSCI',
#    'BR',
#    'WEC',
#    'ADBE',
#    'DHR',
#    'NDAQ',
#    'ELV',
#    'PAYX',
#    'NOW',
#    'TXN',
#    'MRNA',
#    'KR',
#    'SNPS',
#    'UNH',
#    'ARE',
#    'EXR',
#    'AFL',
#    'AZO',
#    'PODD',
#    'CEG',
#    'LMT',
#    'PEP',
#    'SYK',
#    'ROL',
#    'TMO',
#    'VRSN',
#    'CTVA',
#    'FDS',
#    'ATO',
#    'ENPH',
#    'SRE',
#    'TMUS',
#    'FAST',
#    'NVDA',
#    'SPGI',
#    'AWK',
#    'AAPL',
#    'AMZN',
#    'WM',
#    'MNST',
#    'TSLA',
#    'IR',
#    'KLAC',
#    'CINF',
#    'PEG',
#    'HCA',
#    'CMS',
#    'HSY',
#    'AEP',
#    'IDXX',
#    'AVGO',
#    'BRO',
#    'MMC',
#    'SCHW',
#    'DTE',
#    'MSI',
#    'V',
#    'LLY',
#    'ACN',
#    'TDY',
#    'KDP',
#    'PWR',
#    'AEE',
#    'HIG',
#    'MA',
#    'CME',
#    'NFLX',
#    'DXCM',
#    'RSG',
#    'XEL',
#    'ANET',
#    'LHX',
#    'OTIS',
#    'BDX',
#    'EG',
#    'CARR',
#    'VRSK',
#    'LNT',
#    'COST',
#    'CPRT',
#    'FTNT',
#    'MPWR',
#    'AON',
#    'NEE',
#    'VRTX',
#    'DPZ',
#    'LRCX',
#    'ED',
#    'CTAS',
#    'ORLY',
#    'CDW',
#    'CHTR',
#    'CSGP',
#    'HUM',
#    'PAYC',
#    'TTWO',
#    'IEX',
#    'AJG',
#    'WRB',
#    'ALL',
#    'CSCO',
#    'PANW',
#    'NOC',
#    'ODFL',
#    'CDNS',
#    'CZR',
#    'GL',
#    'NI',
#    'NSC',
#    'WTW',
#    'FICO',
#    'MKTX',
#    'PNW'],
#   'groups': {0: ['ABBV', 'PGR', 'JNJ', 'EA', 'MCO'],
#    5: ['MSFT', 'ABT', 'MSCI', 'BR', 'WEC'],
#    10: ['ADBE', 'DHR', 'NDAQ', 'ELV', 'PAYX'],
#    15: ['NOW', 'TXN', 'MRNA', 'KR', 'SNPS'],
#    20: ['UNH', 'ARE', 'EXR', 'AFL', 'AZO'],
#    25: ['PODD', 'CEG', 'LMT', 'PEP', 'SYK'],
#    30: ['ROL', 'TMO', 'VRSN', 'CTVA', 'FDS'],
#    35: ['ATO', 'ENPH', 'SRE', 'TMUS', 'FAST'],
#    40: ['NVDA', 'SPGI', 'AWK', 'AAPL', 'AMZN'],
#    45: ['WM', 'MNST', 'TSLA', 'IR', 'KLAC'],
#    50: ['CINF', 'PEG', 'HCA', 'CMS', 'HSY'],
#    55: ['AEP', 'IDXX', 'AVGO', 'BRO', 'MMC'],
#    60: ['SCHW', 'DTE', 'MSI', 'V', 'LLY'],
#    65: ['ACN', 'TDY', 'KDP', 'PWR', 'AEE'],
#    70: ['HIG', 'MA', 'CME', 'NFLX', 'DXCM'],
#    75: ['RSG', 'XEL', 'ANET', 'LHX', 'OTIS'],
#    80: ['BDX', 'EG', 'CARR', 'VRSK', 'LNT'],
#    85: ['COST', 'CPRT', 'FTNT', 'MPWR', 'AON'],
#    90: ['NEE', 'VRTX', 'DPZ', 'LRCX', 'ED'],
#    95: ['CTAS', 'ORLY', 'CDW', 'CHTR', 'CSGP'],
#    100: ['HUM', 'PAYC', 'TTWO', 'IEX', 'AJG'],
#    105: ['WRB', 'ALL', 'CSCO', 'PANW', 'NOC'],
#    110: ['ODFL', 'CDNS', 'CZR', 'GL', 'NI'],
#    115: ['NSC', 'WTW', 'FICO', 'MKTX', 'PNW']}}}

# %%
final_stats = []

for year in tqdm.tqdm(range(2012,2024)):
    for exploration_rate in np.arange(0.01,0.15,0.01):
        for p_alpha in np.arange(0.005,0.15,0.005):
            st_year = simulate_year(df_2w, [year], n_sims = N_SIMS,
                                    stock_groups = stock_groups[year],
                                    exploration_rate = exploration_rate,
                                    p_alpha = p_alpha
                                   )
            tmp_year = {"year":year,"ex_rate":exploration_rate,
                        "alpha":p_alpha, "return": st_year['mean']}
            final_stats.append(tmp_year)
# Out:
# 100%|██████████████████████████████████████████| 12/12 [33:38<00:00, 168.22s/it]

# %%
df_res = pd.DataFrame(final_stats)
df_groups = df_res.groupby(by=['ex_rate','alpha']).mean()['return'].reset_index()

# %%
dict_perf = {}
for year in range(2012,2023):
    vals = df_res[df_res['year']==year].sort_values(by = 'return').iloc[-1].to_dict()
    dict_perf[year] = vals

# %%
dict_perf_nxt_y = {}
for year in range(2012,2023):
    alpha = dict_perf[year]['alpha']
    ex_rate = dict_perf[year]['ex_rate']
    perf_nxt = df_res[(df_res['year'] == year + 1 ) &\
               (df_res['alpha'] == alpha) &\
               (df_res['ex_rate'] == ex_rate)].iloc[0].to_dict()
    dict_perf_nxt_y[year+1] = perf_nxt

# %%
dict_perf_nxt_y
# Out:
# {2013: {'year': 2013.0,
#   'ex_rate': 0.02,
#   'alpha': 0.14,
#   'return': 0.21590078402811388},
#  2014: {'year': 2014.0,
#   'ex_rate': 0.14,
#   'alpha': 0.030000000000000002,
#   'return': 0.17462882460628112},
#  2015: {'year': 2015.0,
#   'ex_rate': 0.13,
#   'alpha': 0.14,
#   'return': 0.03357007688874637},
#  2016: {'year': 2016.0,
#   'ex_rate': 0.12,
#   'alpha': 0.01,
#   'return': 0.1867605104435387},
#  2017: {'year': 2017.0,
#   'ex_rate': 0.14,
#   'alpha': 0.01,
#   'return': 0.19730938370767834},
#  2018: {'year': 2018.0,
#   'ex_rate': 0.14,
#   'alpha': 0.135,
#   'return': -0.006794253401519834},
#  2019: {'year': 2019.0,
#   'ex_rate': 0.03,
#   'alpha': 0.135,
#   'return': 0.3821387092793392},
#  2020: {'year': 2020.0,
#   'ex_rate': 0.08,
#   'alpha': 0.12000000000000001,
#   'return': 0.2483229004808399},
#  2021: {'year': 2021.0,
#   'ex_rate': 0.04,
#   'alpha': 0.045,
#   'return': 0.3580538977362389},
#  2022: {'year': 2022.0,
#   'ex_rate': 0.01,
#   'alpha': 0.005,
#   'return': -0.11470561394238311},
#  2023: {'year': 2023.0,
#   'ex_rate': 0.05,
#   'alpha': 0.06,
#   'return': 0.12751853773843078}}

# %%
perf = pd.DataFrame(dict_perf_nxt_y).T

# %%
(perf[0:-2]['return'] + 1).cumprod()
# Out:
# 2013    1.215901
# 2014    1.428232
# 2015    1.476178
# 2016    1.751870
# 2017    2.097530
# 2018    2.083279
# 2019    2.879380
# 2020    3.594397
# 2021    4.881384
# Name: return, dtype: float64

# %%
com_ret = (perf['return'] + 1).cumprod()
com_ret_last = com_ret.iloc[-1]

# %%
perf['return'].plot.bar()
# Out:
# <AxesSubplot: >

# %%
N = 11 # number of years (2013 - 2023)
av_a_ret = (com_ret_last)**(1/N)

print("Return final year ", com_ret_last)
print("Average annual return ", av_a_ret)
# Out:
# Return final year  4.872528545160369
# Average annual return  1.1548434794512052
